# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.loc[0:6,'job_title_short']
# Out:
# 0    Senior Data Engineer
# 1            Data Analyst
# 2           Data Engineer
# 3           Data Engineer
# 4           Data Engineer
# 5           Data Engineer
# 6    Senior Data Engineer
# Name: job_title_short, dtype: object

# %%
df.iloc[0:5]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.loc[0:5,'job_title_short':'job_location']
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC
# 5                      Anywhere

# %%
df.loc[0:15,'job_country' == 'United States']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.loc[0:15,'job_country' == 'United States']
#
# File c:\Users\fejle\anaconda3\envs\python_course\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File c:\Users\fejle\anaconda3\envs\python_course\Lib\site-packages\pandas\core\indexing.py:1369, in _LocIndexer._getitem_tuple(self, tup)
#    1367 with suppress(IndexingError):
#    1368     tup = self._expand_ellipsis(tup)
# -> 1369     return self._getitem_lowerdim(tup)
#    1371 # no multi-index, so validate all of the indexers
#    1372 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\fejle\anaconda3\envs\python_course\Lib\site-packages\pandas\core\indexing.py:1066, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1062 for i, key in enumerate(tup):
#    1063     if is_label_like(key):
#    1064         # We don't need to check for tuples here because those are
#    1065         #  caught by the _is_nested_tuple_indexer check above.
# -> 1066         section = self._getitem_axis(key, axis=i)
#    1068         # We should never have a scalar section here, because
#    1069         #  _getitem_lowerdim is only called after a check for
#    1070         #  is_scalar_access, which that would be.
#    1071         if section.ndim == self.ndim:
#    1072             # we're in the middle of slicing through a MultiIndex
#    1073             # revise the key wrt to `section` by inserting an _NS
#
# File c:\Users\fejle\anaconda3\envs\python_course\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1428         return self.obj.iloc[tuple(indexer)]
#    1430 # fall thru to straight lookup
# -> 1431 self._validate_key(key, axis)
#    1432 return self._get_label(key, axis=axis)
#
# File c:\Users\fejle\anaconda3\envs\python_course\Lib\site-packages\pandas\core\indexing.py:1240, in _LocIndexer._validate_key(self, key, axis)
#    1233 ax = self.obj._get_axis(axis)
#    1234 if isinstance(key, bool) and not (
#    1235     is_bool_dtype(ax.dtype)
#    1236     or ax.dtype.name == "boolean"
#    1237     or isinstance(ax, MultiIndex)
#    1238     and is_bool_dtype(ax.get_level_values(0).dtype)
#    1239 ):
# -> 1240     raise KeyError(
#    1241         f"{key}: boolean label can not be used without a boolean index"
#    1242     )
#    1244 if isinstance(key, slice) and (
#    1245     isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1246 ):
#    1247     raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %%
df[df['job_country'] == 'United States'].head(15).sort_values('job_posted_date')
# Out:
#          job_title_short                                          job_title  \
# 35         Data Engineer                        Data Engineer - Royal Canin
# 27         Data Engineer  Principal Data Engineer (Lead), Knowledge Grap...
# 32        Data Scientist   Sr. Data Scientist (NLP) - Full-time / Part-time
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 30  Senior Data Engineer     Senior Data Engineer (Work from home Eligible)
# 9         Data Scientist                                  Data Scientist II
# 17        Data Scientist                             Data Science Team Lead
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 37         Data Engineer                     Data Engineer III - Now Hiring
# 26         Data Engineer                                      Data Engineer
# 11         Data Engineer                                      Data Engineer
# 36          Data Analyst                                       Data Analyst
# 5          Data Engineer                                  GCP Data Engineer
# 13  Senior Data Engineer                               Senior Data Engineer
#
#                           job_location  \
# 35                      St Charles, MO
# 27                   San Francisco, CA
# 32                          Dallas, TX
# 6                         Dearborn, MI
# 30                      Wilmington, DE
# 9                             Anywhere
# 17                          Laurel, MD
# 0                        Watertown, CT
# 3                      San Antonio, TX
# 37                          Boston, MA
# 26                       United States
# 11  Colorado Springs, CO   (+3 others)
# 36                      Des Moines, IA
# 5                             Anywhere
# 13                        New York, NY
#
#                                               job_via  \
# 35                              via My ArkLaMiss Jobs
# 27                                       via LinkedIn
# 32                                       via Snagajob
# 6                                        via LinkedIn
# 30                                      via WDHN Jobs
# 9                                    via ZipRecruiter
# 17  via APL Careers - Johns Hopkins University App...
# 0                                     via Work Nearby
# 3                                   via Diversity.com
# 37                                       via Snagajob
# 26                                       via LinkedIn
# 11                                       via The Muse
# 36                                    via Trabajo.org
# 5                                    via ZipRecruiter
# 13                                       via LinkedIn
#
#            job_schedule_type  job_work_from_home            search_location  \
# 35                 Full-time               False  California, United States
# 27                 Full-time               False                    Georgia
# 32                 Full-time               False       Texas, United States
# 6                  Full-time               False     Florida, United States
# 30                 Full-time               False       Texas, United States
# 9                  Full-time                True    New York, United States
# 17                 Full-time               False                    Georgia
# 0                  Full-time               False       Texas, United States
# 3                  Full-time               False       Texas, United States
# 37                 Full-time               False    Illinois, United States
# 26                 Full-time               False                    Georgia
# 11                 Full-time               False       Texas, United States
# 36                 Full-time               False    Illinois, United States
# 5   Contractor and Temp work                True                    Georgia
# 13                 Full-time               False       Texas, United States
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 35 2023-02-17 13:10:21                   True                  True
# 27 2023-02-18 13:31:24                  False                 False
# 32 2023-03-13 13:07:03                  False                  True
# 6  2023-03-27 13:18:18                  False                 False
# 30 2023-03-29 13:32:03                  False                  True
# 9  2023-04-23 13:02:57                  False                 False
# 17 2023-06-13 13:25:17                  False                  True
# 0  2023-06-16 13:44:15                  False                 False
# 3  2023-07-04 13:01:41                   True                 False
# 37 2023-07-10 13:08:19                  False                  True
# 26 2023-09-15 13:56:18                   True                 False
# 11 2023-11-03 13:06:51                  False                  True
# 36 2023-11-06 13:01:22                  False                  True
# 5  2023-11-07 14:01:59                  False                 False
# 13 2023-11-15 13:08:52                   True                  True
#
#       job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 35  United States        None              NaN              NaN
# 27  United States        None              NaN              NaN
# 32  United States        None              NaN              NaN
# 6   United States        None              NaN              NaN
# 30  United States        None              NaN              NaN
# 9   United States        None              NaN              NaN
# 17  United States        None              NaN              NaN
# 0   United States        None              NaN              NaN
# 3   United States        None              NaN              NaN
# 37  United States        None              NaN              NaN
# 26  United States        None              NaN              NaN
# 11  United States        None              NaN              NaN
# 36  United States        None              NaN              NaN
# 5   United States        None              NaN              NaN
# 13  United States        None              NaN              NaN
#
#                                 company_name  \
# 35                                      Mars
# 27                                Altos Labs
# 32                                  MCKESSON
# 6              Miracle Software Systems, Inc
# 30                               Capital One
# 9                 Radwell International, LLC
# 17  Johns Hopkins Applied Physics Laboratory
# 0                       Boehringer Ingelheim
# 3               Southwest Research Institute
# 37  American Family Mutual Insurance Company
# 26               Infinite Computer Solutions
# 11                                   Philips
# 36                           Assuredpartners
# 5                            smart folks inc
# 13                                     Nayya
#
#                                            job_skills  \
# 35  ['python', 'sql', 'neo4j', 'databricks', 'azur...
# 27                            ['python', 'r', 'java']
# 32  ['python', 'azure', 'databricks', 'pyspark', '...
# 6   ['sql', 'python', 'java', 'sql server', 'gcp',...
# 30  ['scala', 'python', 'nosql', 'mongo', 'shell',...
# 9   ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 17                             ['go', 'apl', 'excel']
# 0                                                None
# 3   ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 37  ['python', 'sql', 'nosql', 'aws', 'gcp', 'azur...
# 26                                               None
# 11                                 ['python', 'qlik']
# 36                                               None
# 5                            ['python', 'sql', 'gcp']
# 13  ['python', 'sql', 'go', 'ruby', 'ruby', 'javas...
#
#                                       job_type_skills
# 35  {'cloud': ['databricks', 'azure'], 'databases'...
# 27           {'programming': ['python', 'r', 'java']}
# 32  {'cloud': ['azure', 'databricks'], 'libraries'...
# 6   {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 30  {'cloud': ['redshift', 'snowflake', 'aws', 'az...
# 9   {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 17  {'analyst_tools': ['excel'], 'programming': ['...
# 0                                                None
# 3   {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 37  {'cloud': ['aws', 'gcp', 'azure'], 'libraries'...
# 26                                               None
# 11  {'analyst_tools': ['qlik'], 'programming': ['p...
# 36                                               None
# 5   {'cloud': ['gcp'], 'programming': ['python', '...
# 13  {'cloud': ['aws'], 'other': ['terraform'], 'pr...
