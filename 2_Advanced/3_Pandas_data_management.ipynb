# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#              job_title_short  \
# 642695        Data Scientist
# 593490   Senior Data Analyst
# 406171         Data Engineer
# 744275          Data Analyst
# 721783  Senior Data Engineer
# 572771         Data Engineer
# 71863         Data Scientist
# 88084          Data Engineer
# 175032        Data Scientist
# 761909          Data Analyst
#
#                                                 job_title  \
# 642695                       Research blockchain Engineer
# 593490                                Senior Data Analyst
# 406171                                  Big Data Engineer
# 744275          Analyst, Pharmaceuticals, Data Management
# 721783  Senior Data Engineer, Federal Marketing - Now ...
# 572771                               Data Center Engineer
# 71863   Chief Data Science and Data Engineering Office...
# 88084                                       Data Engineer
# 175032                             Data Scientist, Expert
# 761909                                       Data Analyst
#
#                                   job_location                      job_via  \
# 642695                                Anywhere                 via LinkedIn
# 593490                          Somerville, MA     via Experimentation Jobs
# 406171                           Rockville, MD                via WANE Jobs
# 744275                                  Canada             via BeBee Canada
# 721783                            Portland, ME                 via Snagajob
# 572771                               Hong Kong       via LinkedIn Hong Kong
# 71863                         Toulouse, France  via Elite Recruitment Group
# 88084   Judean Foothills, Israel   (+2 others)                   via Jobnet
# 175032                             Oakland, CA                    via BeBee
# 761909                Levallois-Perret, France      via Emplois Trabajo.org
#
#               job_schedule_type  job_work_from_home  \
# 642695                Full-time                True
# 593490                Full-time               False
# 406171                Full-time               False
# 744275                Full-time               False
# 721783  Full-time and Part-time               False
# 572771                Full-time               False
# 71863                 Part-time               False
# 88084                 Full-time               False
# 175032                Full-time               False
# 761909                Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 642695                    Ukraine 2023-11-15 12:30:26                  False
# 593490    New York, United States 2023-11-24 09:00:14                   True
# 406171       Texas, United States 2023-02-05 16:07:51                  False
# 744275                     Canada 2023-10-27 20:19:45                  False
# 721783    Illinois, United States 2023-09-15 21:08:39                  False
# 572771                  Hong Kong 2023-11-16 09:22:25                   True
# 71863                      France 2023-10-24 00:19:11                  False
# 88084                      Israel 2023-05-30 00:28:20                  False
# 175032  California, United States 2023-05-16 15:03:51                  False
# 761909                     France 2023-06-05 20:40:23                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 642695                 False        Ukraine        None              NaN
# 593490                 False  United States        None              NaN
# 406171                 False  United States        None              NaN
# 744275                 False         Canada        None              NaN
# 721783                 False  United States        hour              NaN
# 572771                 False      Hong Kong        None              NaN
# 71863                  False         France        None              NaN
# 88084                  False         Israel        None              NaN
# 175032                 False  United States        None              NaN
# 761909                 False         France        None              NaN
#
#         salary_hour_avg                      company_name  \
# 642695              NaN                   Data Science UA
# 593490              NaN                             Velir
# 406171              NaN                        ConsultNet
# 744275              NaN                             Njoyn
# 721783            52.34                              Dell
# 572771              NaN                       Jane Street
# 71863               NaN             EliteRecruitmentGroup
# 88084               NaN                          RecrutiX
# 175032              NaN  Pacific Gas And Electric Company
# 761909              NaN                  Société Générale
#
#                                                job_skills  \
# 642695           ['go', 'rust', 'javascript', 'solidity']
# 593490                                               None
# 406171                  ['sql', 'aws', 'spark', 'hadoop']
# 744275                      ['sas', 'sas', 'r', 'python']
# 721783     ['python', 'sql', 'spark', 'hadoop', 'docker']
# 572771  ['bash', 'python', 'ocaml', 'colocation', 'lin...
# 71863                                             ['aws']
# 88084                                             ['aws']
# 175032         ['sas', 'sas', 'sql', 'python', 'tableau']
# 761909                              ['power bi', 'excel']
#
#                                           job_type_skills
# 642695  {'programming': ['go', 'rust', 'javascript', '...
# 593490                                               None
# 406171  {'cloud': ['aws'], 'libraries': ['spark', 'had...
# 744275  {'analyst_tools': ['sas'], 'programming': ['sa...
# 721783  {'libraries': ['spark', 'hadoop'], 'other': ['...
# 572771  {'cloud': ['colocation'], 'os': ['linux'], 'pr...
# 71863                                  {'cloud': ['aws']}
# 88084                                  {'cloud': ['aws']}
# 175032  {'analyst_tools': ['sas', 'tableau'], 'program...
# 761909           {'analyst_tools': ['power bi', 'excel']}
