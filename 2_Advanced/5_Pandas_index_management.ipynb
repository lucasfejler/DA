# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.index.name = 'job_index'

# %%
df_arg = df[df['job_country'] == 'Argentina']

df_arg.reset_index(inplace=True)
df_arg
# Out:
#       job_index        job_title_short  \
# 0           236         Data Scientist
# 1           417  Senior Data Scientist
# 2           863          Data Engineer
# 3          1131         Data Scientist
# 4          1140      Software Engineer
# ...         ...                    ...
# 8731     785605   Senior Data Engineer
# 8732     785608      Software Engineer
# 8733     785638           Data Analyst
# 8734     785668           Data Analyst
# 8735     785672         Cloud Engineer
#
#                                               job_title  \
# 0                               Científico de Datos LLM
# 1                         Data Science SR Puerto Madero
# 2                                      Data Engineer Jr
# 3                      Data & Applied Intelligence #hub
# 4     Visual Basic Developer (with Data experience) ...
# ...                                                 ...
# 8731          Sr. Data Architect, Professional Services
# ...

# %%
df_arg.set_index('job_index',inplace=True)
df_arg
# Out:
#                  job_title_short  \
# job_index
# 236               Data Scientist
# 417        Senior Data Scientist
# 863                Data Engineer
# 1131              Data Scientist
# 1140           Software Engineer
# ...                          ...
# 785605      Senior Data Engineer
# 785608         Software Engineer
# 785638              Data Analyst
# 785668              Data Analyst
# 785672            Cloud Engineer
#
#                                                    job_title  \
# job_index
# 236                                  Científico de Datos LLM
# 417                            Data Science SR Puerto Madero
# 863                                         Data Engineer Jr
# 1131                        Data & Applied Intelligence #hub
# 1140       Visual Basic Developer (with Data experience) ...
# ...                                                      ...
# 785605             Sr. Data Architect, Professional Services
# ...

# %%
df_arg
# Out:
#                  job_title_short  \
# job_index
# 236               Data Scientist
# 417        Senior Data Scientist
# 863                Data Engineer
# 1131              Data Scientist
# 1140           Software Engineer
# ...                          ...
# 785605      Senior Data Engineer
# 785608         Software Engineer
# 785638              Data Analyst
# 785668              Data Analyst
# 785672            Cloud Engineer
#
#                                                    job_title  \
# job_index
# 236                                  Científico de Datos LLM
# 417                            Data Science SR Puerto Madero
# 863                                         Data Engineer Jr
# 1131                        Data & Applied Intelligence #hub
# 1140       Visual Basic Developer (with Data experience) ...
# ...                                                      ...
# 785605             Sr. Data Architect, Professional Services
# ...

# %%
df_arg.reset_index(inplace=True)

df_arg
# Out:
#       job_index_arg        job_title_short  \
# 0               236         Data Scientist
# 1               417  Senior Data Scientist
# 2               863          Data Engineer
# 3              1131         Data Scientist
# 4              1140      Software Engineer
# ...             ...                    ...
# 8731         785605   Senior Data Engineer
# 8732         785608      Software Engineer
# 8733         785638           Data Analyst
# 8734         785668           Data Analyst
# 8735         785672         Cloud Engineer
#
#                                               job_title  \
# 0                               Científico de Datos LLM
# 1                         Data Science SR Puerto Madero
# 2                                      Data Engineer Jr
# 3                      Data & Applied Intelligence #hub
# 4     Visual Basic Developer (with Data experience) ...
# ...                                                 ...
# ...

# %%
df_arg.set_index('job_index_arg',inplace=True)
df_arg
# Out:
#                      job_title_short  \
# job_index_arg
# 236                   Data Scientist
# 417            Senior Data Scientist
# 863                    Data Engineer
# 1131                  Data Scientist
# 1140               Software Engineer
# ...                              ...
# 785605          Senior Data Engineer
# 785608             Software Engineer
# 785638                  Data Analyst
# 785668                  Data Analyst
# 785672                Cloud Engineer
#
#                                                        job_title  \
# job_index_arg
# 236                                      Científico de Datos LLM
# 417                                Data Science SR Puerto Madero
# 863                                             Data Engineer Jr
# 1131                            Data & Applied Intelligence #hub
# 1140           Visual Basic Developer (with Data experience) ...
# ...                                                          ...
# ...

# %%
df_arg.pivot_table(index='job_title_short',values='salary_year_avg',aggfunc=['min','max','median'])
# Out:
#                                       min             max          median
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  63000.0         79200.0        71100.00
# Cloud Engineer                   197500.0        197500.0       197500.00
# Data Analyst                      45000.0        111202.0        92771.75
# Data Engineer                     50400.0        147500.0        96773.00
# Data Scientist                    50400.0        207500.0        71000.00
# Machine Learning Engineer         70000.0        222000.0       101029.00
# Senior Data Engineer             147500.0        147500.0       147500.00
# Software Engineer                174500.0        174500.0       174500.00

# %%
df_arg.drop(columns=['salary_hour_avg'],inplace=True)
df_arg
# Out:
# C:\Users\fejle\AppData\Local\Temp\ipykernel_16576\2999100031.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_arg.drop(columns=['salary_hour_avg'],inplace=True)
#                          job_title_short  \
# job_index_arg
# 22620                      Data Engineer
# 64412                      Data Engineer
# 78382                      Data Engineer
# 93501                       Data Analyst
# 104117                     Data Engineer
# 107338                    Data Scientist
# 119738              Senior Data Engineer
# 135531         Machine Learning Engineer
# 152274                    Data Scientist
# 171432                     Data Engineer
# 187628                    Cloud Engineer
# 204569                 Software Engineer
# 213345         Machine Learning Engineer
# ...
