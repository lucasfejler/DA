# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
median_salary_year = df['salary_year_avg'].median()

# %%
median_salary_hour = df['salary_hour_avg'].median()

# %%
df_filled = df

df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(median_salary_hour)

# %%
df_filled.loc[:5,['salary_year_avg','job_title_short']]
# Out:
#    salary_year_avg       job_title_short
# 0         115000.0  Senior Data Engineer
# 1         115000.0          Data Analyst
# 2         115000.0         Data Engineer
# 3         115000.0         Data Engineer
# 4         115000.0         Data Engineer
# 5         115000.0         Data Engineer

# %%
df_unique = df_filled

df_unique = df_unique.drop_duplicates(subset=['job_title','company_name'])

print('The amount of duplicated rows were',len(df_filled) - len(df_unique))
# Out:
# The amount of duplicated rows were 277699

# %%
df_unique.dropna()
# Out:
#               job_title_short  \
# 28             Data Scientist
# 51       Senior Data Engineer
# 77              Data Engineer
# 92              Data Engineer
# 100            Data Scientist
# ...                       ...
# 785330  Senior Data Scientist
# 785395          Data Engineer
# 785488         Data Scientist
# 785624          Data Engineer
# 785682         Data Scientist
#
#                                                 job_title  \
# 28                                    CRM Data Specialist
# 51                                   Senior Data Engineer
# 77                                          Data Engineer
# 92                Remote - Data Engineer - Permanent - W2
# 100               Data Scientist, Risk Data Mining - USDS
# ...                                                   ...
# 785330  Senior Data Scientist - TikTok US - Tech Services
# 785395  Senior Consultant - Tech Consulting -Azure Dat...
# 785488                                     Data Scientist
# 785624                   Data Analytics Engineer (Hybrid)
# 785682  Data Scientist für datengetriebene Entwicklung...
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 51                                     Anywhere     via LinkedIn
# 77                                Arlington, VA     via LinkedIn
# 92                                     Anywhere     via LinkedIn
# 100                           Mountain View, CA     via LinkedIn
# ...                                         ...              ...
# 785330                          Los Angeles, CA     via LinkedIn
# 785395                                    India  via Ai-Jobs.net
# 785488                             New York, NY        via BeBee
# 785624                          Mt Prospect, IL  via Ai-Jobs.net
# 785682                      Reutlingen, Germany  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 28             Full-time               False                 Costa Rica
# 51            Contractor                True    Illinois, United States
# 77             Full-time               False                      Sudan
# 92             Full-time                True    Illinois, United States
# 100            Full-time               False  California, United States
# ...                  ...                 ...                        ...
# 785330         Full-time               False  California, United States
# 785395         Full-time               False                      India
# 785488         Full-time               False    New York, United States
# 785624         Full-time               False    Illinois, United States
# 785682         Full-time               False                    Germany
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28     2023-08-01 13:37:57                  False                 False
# 51     2023-06-21 13:09:39                  False                 False
# 77     2023-06-26 14:22:54                  False                 False
# 92     2023-02-21 13:29:59                  False                  True
# 100    2023-07-31 13:01:18                  False                  True
# ...                    ...                    ...                   ...
# 785330 2023-01-11 06:20:33                  False                  True
# 785395 2023-12-19 06:10:41                  False                 False
# 785488 2023-11-27 06:01:23                  False                 False
# 785624 2023-08-31 06:02:16                  False                  True
# 785682 2023-03-04 06:16:08                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28         Costa Rica        year         109500.0            45.98
# 51      United States        hour         115000.0            72.50
# 77              Sudan        year         140000.0            45.98
# 92      United States        year         120000.0            45.98
# 100     United States        year         228222.0            45.98
# ...               ...         ...              ...              ...
# 785330  United States        year         200935.5            45.98
# 785395          India        year          64800.0            45.98
# 785488  United States        year         115000.0            45.98
# 785624  United States        year         139216.0            45.98
# 785682        Germany        year         157500.0            45.98
#
#             company_name                                         job_skills  \
# 28              Netskope                                  ['gdpr', 'excel']
# 51      Aditi Consulting   ['python', 'java', 'aws', 'databricks', 'spark']
# 77            Intelletec  ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92          Apex Systems                                  ['sql', 'python']
# 100               TikTok                  ['sql', 'r', 'python', 'express']
# ...                  ...                                                ...
# 785330            TikTok                             ['sql', 'python', 'r']
# 785395                EY  ['sql', 'python', 'azure', 'databricks', 'spar...
# 785488       Winston Fox                                    ['python', 'r']
# 785624       Bosch Group  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785682       Bosch Group  ['python', 'hadoop', 'spark', 'airflow', 'kube...
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 51      {'cloud': ['aws', 'databricks'], 'libraries': ...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# ...                                                   ...
# 785330            {'programming': ['sql', 'python', 'r']}
# 785395  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 785488                   {'programming': ['python', 'r']}
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
#
# [18148 rows x 17 columns]

# %%
df.drop_duplicates()
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None         115000.0            45.98
# 1              Mexico        None         115000.0            45.98
# 2             Germany        None         115000.0            45.98
# 3       United States        None         115000.0            45.98
# 4               Sudan        None         115000.0            45.98
# ...               ...         ...              ...              ...
# 785736      Singapore        None         115000.0            45.98
# 785737        Germany        None         115000.0            45.98
# 785738       Malaysia        None         115000.0            45.98
# 785739          Sudan        None         115000.0            45.98
# 785740          India        None         115000.0            45.98
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785640 rows x 17 columns]

# %%
df['salary_hour_avg'].fillna('ahora ta yeno')
# Out:
# 0         45.98
# 1         45.98
# 2         45.98
# 3         45.98
# 4         45.98
#           ...
# 785736    45.98
# 785737    45.98
# 785738    45.98
# 785739    45.98
# 785740    45.98
# Name: salary_hour_avg, Length: 785741, dtype: float64
